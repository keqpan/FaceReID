# %%
from PIL import Image
import os

# %%
datasets_path = "/home/safin/datasets/"
Image.open(os.path.join(datasets_path, "CASIA-WebFace-112X96", "0000045", "001.jpg"))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=96x112 at 0x7F2CDBEF2EF0>

# %%
"/home/safin/datasets/CASIA-maxpy-clean/

# %%
Image.open(os.path.join(datasets_path, "CASIA-WebFace/CASIA-WebFace-sphereface", "0000045", "001.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=100x116 at 0x7F2CF0293198>

# %%
Image.open(os.path.join(datasets_path, "CASIA-maxpy-clean", "0000045", "001.jpg"))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x7F2CDBFC8DA0>

# %%
import os

# traverse root directory, and list directories as dirs and files as files
sphereface_aligned = set()
for root, dirs, files in os.walk("/home/safin/datasets/CASIA-WebFace-112X96"):
    for file in files:
        item = os.path.join(os.path.basename(root), os.path.splitext(file)[0])
        sphereface_aligned.add(item)

#     path = root.split(os.sep)
#     print((len(path) - 1) * '---', os.path.basename(root))
#     for file in files:
#         print(len(path) * '---', file)

# %%
my_aligned = set()
for root, dirs, files in os.walk("/home/safin/datasets/CASIA-WebFace/CASIA-WebFace-sphereface/"):
    for file in files:
        item = os.path.join(os.path.basename(root), os.path.splitext(file)[0])
        my_aligned.add(item)

# %%
clean_aligned = set()
for root, dirs, files in os.walk("/home/safin/datasets/CASIA-maxpy-clean/"):
    for file in files:
        item = os.path.join(os.path.basename(root), os.path.splitext(file)[0])
        clean_aligned.add(item)

# %%
len(sphereface_aligned)
# Out:
# 490871

# %%
len(my_aligned)
# Out:
# 454590

# %%
len(clean_aligned)
# Out:
# 455594

# %%
sphereface_aligned-my_aligned
# Out:
# {'0005527/398',
#  '2096077/022',
#  '0005489/042',
#  '0001127/125',
#  '3922289/008',
#  '0706787/006',
#  '1497668/041',
#  '0059215/167',
#  '3254521/004',
#  '0133448/001',
#  '1813088/016',
#  '0719637/091',
#  '0776040/015',
#  '0718646/079',
#  '1500155/125',
#  '2284582/012',
#  '1719342/170',
#  '0748973/143',
#  '1776088/007',
#  '0429348/002',
#  '3692767/006',
#  '0460694/041',
#  '1483339/009',
#  '0100866/277',
#  '0059215/205',
#  '1197462/004',
#  '2753160/007',
#  '0001407/001',
#  '0383966/040',
#  '2789553/014',
#  '3405146/067',
#  '0223213/030',
#  '1519666/069',
#  '1169428/050',
#  '1102140/289',
#  '0707476/116',
#  '1754593/064',
#  '0005281/050',
#  '3374941/018',
#  '0001710/189',
#  '1128390/014',
#  '6573530/033',
#  '0006969/022',
#  '4477072/011',
#  '0001265/016',
#  '2162024/116',
#  '1008191/002',
#  '2389665/035',
#  '0305519/012',
#  '0001738/005',
#  '0010736/123',
#  '1312421/007',
#  '0386472/050',
#  '2158763/003',
#  '0000655/040',
# ...

# %%
os.path.join(os.path.basename(root), file)
# Out:
# '0596404/006.jpg'

# %%
s=set()

# %%
s.add(6)

# %%
s
# Out:
# {'0596404/001',
#  '0596404/002',
#  '0596404/003',
#  '0596404/004',
#  '0596404/005',
#  '0596404/006',
#  '0596404/007',
#  '0596404/008',
#  '0596404/009',
#  '0596404/010',
#  '0596404/011',
#  '0596404/012',
#  '0596404/013',
#  '0596404/014',
#  '0596404/015',
#  '0596404/016',
#  '0596404/017',
#  '0596404/018',
#  '0596404/019',
#  '0596404/020',
#  '0596404/021',
#  '0596404/022',
#  '0596404/023',
#  '0596404/024',
#  '0596404/025',
#  '0596404/026',
#  '0596404/027',
#  '0596404/028',
#  '0596404/029',
#  '0596404/030',
#  '0596404/031',
#  '0596404/032',
#  '0596404/033',
#  '0596404/034',
#  '0596404/035',
#  '0596404/036',
#  '0596404/037',
#  '0596404/038',
#  '0596404/039',
#  '0596404/040',
#  '0596404/041',
#  '0596404/042',
#  '0596404/043',
#  '0596404/044',
#  '0596404/045',
#  '0596404/046',
#  '0596404/047',
#  '0596404/048',
#  '0596404/049',
#  '0596404/050',
#  '0596404/051',
#  '0596404/052',
#  '0596404/053',
#  '0596404/054',
#  '0596404/055',
# ...
